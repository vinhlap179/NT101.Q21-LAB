# %%
# !openssl s_client -connect facebook.com:443 -showcerts
# Out:
# CONNECTED(00000003)
# depth=2 C = US, O = DigiCert Inc, OU = www.digicert.com, CN = DigiCert Global Root G2
# verify return:1
# depth=1 C = US, O = DigiCert Inc, CN = DigiCert Global G2 TLS RSA SHA256 2020 CA1
# verify return:1
# depth=0 C = US, ST = California, L = Menlo Park, O = "Meta Platforms, Inc.", CN = *.facebook.com
# verify return:1
# ---
# Certificate chain
#  0 s:C = US, ST = California, L = Menlo Park, O = "Meta Platforms, Inc.", CN = *.facebook.com
#    i:C = US, O = DigiCert Inc, CN = DigiCert Global G2 TLS RSA SHA256 2020 CA1
#    a:PKEY: id-ecPublicKey, 256 (bit); sigalg: RSA-SHA256
#    v:NotBefore: Jan 15 00:00:00 2026 GMT; NotAfter: Apr 15 23:59:59 2026 GMT
# -----BEGIN CERTIFICATE-----
# MIIGpTCCBY2gAwIBAgIQBT5WBhx+YZLxo9qA+oNixzANBgkqhkiG9w0BAQsFADBZ
# MQswCQYDVQQGEwJVUzEVMBMGA1UEChMMRGlnaUNlcnQgSW5jMTMwMQYDVQQDEypE
# aWdpQ2VydCBHbG9iYWwgRzIgVExTIFJTQSBTSEEyNTYgMjAyMCBDQTEwHhcNMjYw
# MTE1MDAwMDAwWhcNMjYwNDE1MjM1OTU5WjBvMQswCQYDVQQGEwJVUzETMBEGA1UE
# ...

# %%
# %%writefile c0.pem
# -----BEGIN CERTIFICATE-----
# MIIGpTCCBY2gAwIBAgIQBT5WBhx+YZLxo9qA+oNixzANBgkqhkiG9w0BAQsFADBZ
# MQswCQYDVQQGEwJVUzEVMBMGA1UEChMMRGlnaUNlcnQgSW5jMTMwMQYDVQQDEypE
# aWdpQ2VydCBHbG9iYWwgRzIgVExTIFJTQSBTSEEyNTYgMjAyMCBDQTEwHhcNMjYw
# MTE1MDAwMDAwWhcNMjYwNDE1MjM1OTU5WjBvMQswCQYDVQQGEwJVUzETMBEGA1UE
# CBMKQ2FsaWZvcm5pYTETMBEGA1UEBxMKTWVubG8gUGFyazEdMBsGA1UEChMUTWV0
# YSBQbGF0Zm9ybXMsIEluYy4xFzAVBgNVBAMMDiouZmFjZWJvb2suY29tMFkwEwYH
# KoZIzj0CAQYIKoZIzj0DAQcDQgAEVPfmMqEUCoHQDhYXsVzoczbK44u6KFMxXe2p
# I7ptmwIoDjmuv56sigGZVjcmvUPabldD/T8fLg1+Z94WnmrmuaOCBBwwggQYMB8G
# A1UdIwQYMBaAFHSFgMBmx9833s+9KTeqAx2+7c0XMB0GA1UdDgQWBBR5ueSG/Qi0
# 3g13/1C1o0VE4p/ITzCBtQYDVR0RBIGtMIGqgg4qLmZhY2Vib29rLmNvbYIOKi5m
# YWNlYm9vay5uZXSCCyouZmJjZG4ubmV0ggsqLmZic2J4LmNvbYIQKi5tLmZhY2Vi
# b29rLmNvbYIPKi5tZXNzZW5nZXIuY29tgg4qLnh4LmZiY2RuLm5ldIIOKi54eS5m
# YmNkbi5uZXSCDioueHouZmJjZG4ubmV0ggxmYWNlYm9vay5jb22CDW1lc3Nlbmdl
# Out:
# Overwriting c1.pem

# %%
# !openssl x509 -in c1.pem -noout -modulus
# Out:
# Modulus=...

# %%
# !openssl x509 -in c1.pem -text -noout | grep "Exponent"
# Out:
#                 Exponent: 65537 (0x10001)

# %%
# !openssl x509 -in c0.pem -text -noout
# Out:
# Certificate:
#     Data:
#         Version: 3 (0x2)
#         Serial Number:
#             05:3e:56:06:1c:7e:61:92:f1:a3:da:80:fa:83:62:c7
#         Signature Algorithm: sha256WithRSAEncryption
#         Issuer: C = US, O = DigiCert Inc, CN = DigiCert Global G2 TLS RSA SHA256 2020 CA1
#         Validity
#             Not Before: Jan 15 00:00:00 2026 GMT
#             Not After : Apr 15 23:59:59 2026 GMT
#         Subject: C = US, ST = California, L = Menlo Park, O = "Meta Platforms, Inc.", CN = *.facebook.com
#         Subject Public Key Info:
#             Public Key Algorithm: id-ecPublicKey
#                 Public-Key: (256 bit)
#                 pub:
#                     04:54:f7:e6:32:a1:14:0a:81:d0:0e:16:17:b1:5c:
#                     e8:73:36:ca:e3:8b:ba:28:53:31:5d:ed:a9:23:ba:
#                     6d:9b:02:28:0e:39:ae:bf:9e:ac:8a:01:99:56:37:
#                     26:bd:43:da:6e:57:43:fd:3f:1f:2e:0d:7e:67:de:
#                     16:9e:6a:e6:b9
# ...

# %%
# %%writefile sig.txt
# 05:49:5d:c6:27:35:c1:50:0e:6d:11:d1:ea:65:ad:23:ac:28:
#         e0:92:34:33:b8:74:d5:68:46:74:6f:68:0f:3a:c1:3d:46:45:
#         b0:44:eb:8e:6b:44:3b:a8:d1:17:96:ec:09:41:70:e8:4d:3d:
#         39:5f:df:f9:6a:40:e9:0e:2c:dd:cc:6f:8e:e6:06:56:28:7c:
#         c1:94:e9:cd:ee:e8:e4:82:58:87:cb:a3:ab:7e:77:ed:83:56:
#         dd:ff:0d:a6:14:d9:de:f1:72:1f:7f:d8:3f:ff:64:04:cb:c9:
#         13:85:38:95:f0:9c:e8:81:bc:7f:85:66:a0:30:b3:67:3a:e8:
#         63:b1:6a:5a:a1:da:26:db:e5:83:c9:84:dc:92:c5:b9:be:6d:
#         c0:a3:35:92:46:a9:d0:43:84:a3:73:da:e5:3a:cb:e6:3a:db:
#         d5:ce:28:1f:0a:a6:33:44:47:23:14:31:43:e4:e1:3a:ee:b2:
#         49:9e:fd:23:ac:9f:b2:af:ca:fc:3e:c9:b8:da:25:9c:a7:03:
#         47:04:a3:12:99:b2:b6:d0:fa:d8:e6:e0:bf:21:cb:1d:8f:63:
#         af:e2:73:71:e1:5f:a6:dc:da:e5:0a:d2:40:a1:d2:61:c8:fe:
#         8d:7f:1d:86:e2:1f:90:a1:3f:e6:a6:3d:5b:e7:14:00:e4:2c:
#         72:85:7a:18
# Out:
# Overwriting sig.txt

# %%
# !cat sig.txt | tr -d '[:space:]:' > signature_clean.txt

# %%
# !cat signature_clean.txt
# Out:
# ...

# %%
# !openssl asn1parse -in c0.pem
# Out:
#     0:d=0  hl=4 l=1701 cons: SEQUENCE
#     4:d=1  hl=4 l=1421 cons: SEQUENCE
#     8:d=2  hl=2 l=   3 cons: cont [ 0 ]
#    10:d=3  hl=2 l=   1 prim: INTEGER           :02
#    13:d=2  hl=2 l=  16 prim: INTEGER           :053E56061C7E6192F1A3DA80FA8362C7
#    31:d=2  hl=2 l=  13 cons: SEQUENCE
#    33:d=3  hl=2 l=   9 prim: OBJECT            :sha256WithRSAEncryption
#    44:d=3  hl=2 l=   0 prim: NULL
#    46:d=2  hl=2 l=  89 cons: SEQUENCE
#    48:d=3  hl=2 l=  11 cons: SET
#    50:d=4  hl=2 l=   9 cons: SEQUENCE
#    52:d=5  hl=2 l=   3 prim: OBJECT            :countryName
#    57:d=5  hl=2 l=   2 prim: PRINTABLESTRING   :US
#    61:d=3  hl=2 l=  21 cons: SET
#    63:d=4  hl=2 l=  19 cons: SEQUENCE
#    65:d=5  hl=2 l=   3 prim: OBJECT            :organizationName
#    70:d=5  hl=2 l=  12 prim: PRINTABLESTRING   :DigiCert Inc
#    84:d=3  hl=2 l=  51 cons: SET
#    86:d=4  hl=2 l=  49 cons: SEQUENCE
#    88:d=5  hl=2 l=   3 prim: OBJECT            :commonName
# ...

# %%
# !openssl asn1parse -in c0.pem -strparse 4 -out c0_body.bin
# Out:
#     0:d=0  hl=4 l=1421 cons: SEQUENCE
#     4:d=1  hl=2 l=   3 cons: cont [ 0 ]
#     6:d=2  hl=2 l=   1 prim: INTEGER           :02
#     9:d=1  hl=2 l=  16 prim: INTEGER           :053E56061C7E6192F1A3DA80FA8362C7
#    27:d=1  hl=2 l=  13 cons: SEQUENCE
#    29:d=2  hl=2 l=   9 prim: OBJECT            :sha256WithRSAEncryption
#    40:d=2  hl=2 l=   0 prim: NULL
#    42:d=1  hl=2 l=  89 cons: SEQUENCE
#    44:d=2  hl=2 l=  11 cons: SET
#    46:d=3  hl=2 l=   9 cons: SEQUENCE
#    48:d=4  hl=2 l=   3 prim: OBJECT            :countryName
#    53:d=4  hl=2 l=   2 prim: PRINTABLESTRING   :US
#    57:d=2  hl=2 l=  21 cons: SET
#    59:d=3  hl=2 l=  19 cons: SEQUENCE
#    61:d=4  hl=2 l=   3 prim: OBJECT            :organizationName
#    66:d=4  hl=2 l=  12 prim: PRINTABLESTRING   :DigiCert Inc
#    80:d=2  hl=2 l=  51 cons: SET
#    82:d=3  hl=2 l=  49 cons: SEQUENCE
#    84:d=4  hl=2 l=   3 prim: OBJECT            :commonName
# ...

# %%
# !sha256sum c0_body.bin
# Out:
# 69432316407577e1941d455e99eb01398e31d3c75fde437723acb90a08039112  c0_body.bin

# %%
import hashlib
S_hex = "..."
n_hex = "..."
e = 65537

S = int(S_hex, 16)
n = int(n_hex, 16)

# giải mã rsa
em_prime = pow(S, e, n)
em_prime_hex = hex(em_prime)[2:]

h_actual = "69432316407577e1941d455e99eb01398e31d3c75fde437723acb90a08039112"
print(f"Giá trị EM giải mã được (dạng Hex):\n...{em_prime_hex[-70:]}\n")
if h_actual in em_prime_hex:
    print("Xác minh đúng")
else:
    print("xác minh sai")
# Out:
# Giá trị EM giải mã được (dạng Hex):
# ...00042069432316407577e1941d455e99eb01398e31d3c75fde437723acb90a08039112
#
# Xác minh đúng
